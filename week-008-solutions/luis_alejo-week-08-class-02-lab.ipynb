# %% [markdown]
# <div style="background: #000;
#             color: #FFF;
#             margin: 0px;
#                 padding: 10px 0px 20px 0px;
#             text-align: center;
#                 ">
#     <h1>Week 8 - Class 2 - Lab</h1>
# </div>

# %% [markdown]
# # Question 1:
#
# In your own words, why might we need both crawling and scraping in a piece of code?

# %% [raw]
# Web crawling and scraping are a good way to extract info and derive a conclusion. Crawling let's us reuse data where scraping lets us "create" new data or an analysis of the existing data.

# %% [markdown]
# # Exercise 1:
#
# Write the code that accesses the h3 tag in the following html.

# %%
from bs4 import BeautifulSoup

html = \
"""
<html>
  <head>
    <title>our webpage</title>
  </head>
  <body>
    <header>
      <h1>hello world</h1>
      <div>
        <h3>tag line</h3>
      </div>
    </header>
    <p>paragraph</p>
    <ul>
      <li><a href='#' id='link1'>link 1</a></li>
      <li><a href='#' id='link2'>link 2</a></li>
      <li><a href='#' id='link3'>link 3</a></li>
    </ul>
  </body>
</html>
"""

# write your code below:

soup = BeautifulSoup(html)

soup.h3
# Out:
# <h3>tag line</h3>

# %% [markdown]
# # Exercise 2
#
# Create a function that will take a list of web pages and return a list of all the anchor tags on those pages.

# %%
import requests

def get_links(urls):
    links = []
    for url in urls:
        res = requests.get(url)
        soup = BeautifulSoup(res.text)
        tags = soup.find_all('a')
        links += [tag for tag in tags]
    return links

list_of_urls = ["https://www.theknowledgehouse.org", 'https://www.politico.com/2020-election/results/', 'http://www.cnn.com']

get_links(list_of_urls)
# Out:
# [<a href="#">About</a>,
#  <a class="mp-back" href="#">back<i class="fas fa-chevron-right icon"></i></a>,
#  <a href="/about/">Our Story</a>,
#  <a href="/team/">Team</a>,
#  <a href="/support/">Supporters</a>,
#  <a href="#">Our Programs</a>,
#  <a class="mp-back" href="#">back<i class="fas fa-chevron-right icon"></i></a>,
#  <a href="/apply/">Innovation Fellowship</a>,
#  <a href="/FrenchMontana/">Kharim Karbouch Coding Fellowship</a>,
#  <a href="#">Partner</a>,
#  <a class="mp-back" href="#">back<i class="fas fa-chevron-right icon"></i></a>,
#  <a href="/employ/">Hire our Graduates</a>,
#  <a href="/get-involved/">Get Involved</a>,
#  <a href="https://www.classy.org/campaign/sponsor-a-fellow-change-a-life/c295935">Become a Champion</a>,
#  <a href="/events/">Events</a>,
#  <a href="/news/">News</a>,
#  <a href="/contact/">Contact Us</a>,
#  <a href="/donate/">Donate</a>,
#  <a class="mt-1 mr-1" id="trigger">
# ...

# %% [markdown]
# # Exercise 3:
#
# Create a function that accesses a web page and returns data from that page.

# %%
def collect_data(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text)
    span = soup.span
    
    return span.contents[0]

    
collect_data("https://www.nba.com/")
# Out:
# <span class="NavHamburger_inner__3JXnL"><span class="invisible">Navigation Toggle</span></span>
